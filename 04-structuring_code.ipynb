# %% [markdown]
# # Structuring code
# Python statements (code in general) are usually stored in files. Let's see [how these files can be organized](https://stephensugden.com/crash_into_python/CodeOrganization.html) in the file-system and how to structure this code.

# %% [markdown]
# ## [Packages](https://docs.python.org/3/tutorial/modules.html#packages)
#
# Packages contain modules (files) and other packages (directories). Example:
# <!--
# ```
# package1/
#     __init__.py
#     module1.py
#     package2/
#         __init__.py
#         module2.py
# ``` -->

# %%
! tree package1/
# Out:
# package1/
# ├── __init__.py
# ├── __init__.pyc
# ├── __init__.py~
# ├── __main__.py
# ├── __pycache__
# │   ├── __init__.cpython-35.pyc
# │   └── module1.cpython-35.pyc
# ├── module1.py
# ├── module1.pyc
# ├── module1.py~
# └── package2
#     ├── __init__.py
#     ├── __init__.pyc
#     ├── __init__.py~
#     ├── __main__.py
#     ├── __pycache__
#     │   ├── __init__.cpython-35.pyc
#     │   └── module2.cpython-35.pyc
#     ├── module2.py
#     ├── module2.pyc
#     └── module2.py~
#
# 3 directories, 18 files

# %% [markdown]
# All packages must have a `__init__.py` (even empty) file. The content of these files are executed when the modules are imported:

# %%
! cat ./package1/__init__.py
# Out:
# print("package1/__init__.py executed")
# from . import module1
# from package1 import package2

# %%
! cat ./package1/module1.py
# Out:
# print("package1/module1.py executed")
# a = 1

# %%
! cat ./package1/package2/__init__.py
# Out:
# print("package1/package2/__init__.py excuted")
# from . import module2

# %%
! cat ./package1/package2/module2.py
# Out:
# print("package1/package2/module2.py executed")
# b = 2

# %%
! python -c 'import package1'
# Out:
# package1/__init__.py executed
# package1/module1.py executed
# package1/package2/__init__.py excuted
# package1/package2/module2.py executed

# %%
! python -c 'import package1.package2'
# Out:
# package1/__init__.py executed
# package1/module1.py executed
# package1/package2/__init__.py excuted
# package1/package2/module2.py executed

# %%
! (cd ./package1; python -c 'import package2')
# Out:
# package1/package2/__init__.py excuted
# package1/package2/module2.py executed

# %% [markdown]
# ## [Modules](https://docs.python.org/3/tutorial/modules.html)
# Modules contain classes, functions, variables and executable statements. Modules can be also imported:

# %%
! (cd ./package1; python -c "import module1" )

# %% [markdown]
# All objects declared in modules are public.

# %%
! (cd ./package1; python -c "import module1; print(dir(module1))" )
# Out:
# package1/module1.py executed
# ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'a']
# ('a =', 1)

# %%
! (cd ./package1; python -c "import module1; print('a =',module1.a)" )
# Out:
# package1/module1.py executed
# ('a =', 1)

# %% [markdown]
# ## Objects, statements and functions
# [Objects](https://docs.python.org/3/tutorial/classes.html) (instantation of classes) contain [statements](https://docs.python.org/3/reference/simple_stmts.html), [functions](http://www.learnpython.org/en/Functions) and other objects.

# %%
class A:
    a = 1
    def say_something_to(self, b):
        print('Hi', b)
        
print('A.a =', A.a)
x = A()
x.say_something_to('you!')
# Out:
# A.a = 1
# Hi you!

# %% [markdown]
# ## [Names, namespaces and scopes](https://www.programiz.com/python-programming/namespace)

# %% [markdown]
# ### Names

# %% [markdown]
# The `id()` funtion returns the address of a object:

# %%
id(1)
# Out:
# 4456089680

# %% [markdown]
# Create a *name* (reference) to an object:

# %%
a=1
id(a) # "a" is not a new object
# Out:
# 4456089680

# %% [markdown]
# Different objects have different id's:

# %%
id(2)
# Out:
# 4456089712

# %% [markdown]
# ### Namespaces

# %% [markdown]
# A *namespace* is a collection of names. All packages, modules, classes and functions define their own namespace (basically, the variables locally defined).

# %% [markdown]
# To show the names of a namespace, we use the built-in function `dir()`:

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %% [markdown]
# ### Scope

# %% [markdown]
# The scope is the region of code where a names (of a namespace) can be accessed without any prefix.

# %%
print(dir()) # Shows the names of the current scope
# Out:
# ['A', 'In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_18', '_19', '_20', '_22', '_23', '_24', '_25', '_26', '_27', '_28', '_34', '_36', '_37', '_38', '_4', '_47', '_48', '_49', '_5', '_50', '_51', '_59', '_6', '_60', '_62', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i37', '_i38', '_i39', '_i4', '_i40', '_i41', '_i42', '_i43', '_i44', '_i45', '_i46', '_i47', '_i48', '_i49', '_i5', '_i50', '_i51', '_i52', '_i53', '_i54', '_i55', '_i56', '_i57', '_i58', '_i59', '_i6', '_i60', '_i61', '_i62', '_i63', '_i64', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'i', 'inspect', 'quit', 'types', 'x']

# %% [markdown]
# In any part of the code, we can get the local scope and the global scope.

# %%
__
# Out:
# ['A',
#  'In',
#  'Out',
#  '_',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_34',
#  '_36',
#  '_37',
#  '_38',
#  '_4',
#  '_47',
#  '_48',
#  '_49',
#  '_5',
#  '_50',
#  '_51',
#  '_59',
#  '_6',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'a',
#  'exit',
#  'get_ipython',
#  'i',
#  'inspect',
#  'quit',
#  'types',
#  'x']

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'a=1\nprint(def(a), def(1))', 'a=1\nprint(id(a), id(1))', 'print(id(1))', 'id(1)', 'a=1\nid(a)', 'id(2)', 'A *namespace* is a collection of names:', 'dir()', '.__dict__', '__dict__', '__builtin__', '__builtin__.__dict__', 'globals()', 'locals()', 'locals()==globals()', 'help(dir)', 'dir(a)', 'dir()', 'dir(_)', 'dir()', 'print(dir())', 'type(_)', 'type(In)', 'type(quit)', 'type(exit)', 'type(a)', 'type(__builtin__)', 'type(__builtins__)', 'for i in dir():\n    print(i)', 'types=()\nfor i in dir():\n    print(i)', 'types=()\nfor i in dir():\n    types += i', 'types=()\nfor i in dir():\n    types.add(i)', 'types=set()\nfor i in dir():\n    types.add(i)', 'types=set()\nfor i in dir():\n    types.add(i)\ntypes', 'types=set()\nfor i in dir():\n    types.add(type(i)\ntypes', 'types=set()\nfor i in dir():\n    types.add(type(i))\ntypes', 'types=set()\nfor i in dir():\n    type(i)\n    types.add(type(i))\ntypes', 'types=set()\nfor i in dir():\n    print(type(i))\n    types.add(type(i))\ntypes', 'types=set()\nfor i in dir():\n    print(type(i))\n    types.add(type(i))\ntypes\nprint(dir())', 'types=set()\nfor i in dir():\n    types.add(type(i))\ntypes\nprint(dir())', 'types=set()\nfor i in dir():\n    types.add(type(i))\ntypes\nprint(dir(In))', 'types=set()\nfor i in dir():\n    types.add(type(i))\n#types\nprint(dir(In))', 'types=set()\nfor i in dir():\n    types.add(type(i))\n#types\nprint(type(dir(In)))', "types=set()\nfor i in dir():\n    print(i, end=' ')\n    types.add(type(i))\n#types\nprint(type(dir(In)))", "types=set()\nfor i in enumearte(dir()):\n    print(i, end=' ')\n    types.add(type(i))\n#types\nprint(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    print(i, end=' ')\n    types.add(type(i))\n#types\nprint(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    #print(i, end=' ')\n    types.add(type(i))\ntypes\n#print(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    print(i, end=' ')\n    types.add(type(i))\ntypes\n#print(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    print(i, end=' ')\n    types.add(type(i[1]))\ntypes\n#print(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    print(type(i), end=' ')\n    types.add(type(i[1]))\ntypes\n#print(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    print(type(i[1]), end=' ')\n    types.add(type(i[1]))\ntypes\n#print(type(dir(In)))", "types=set()\nfor i in enumerate(dir()):\n    #print(type(i[1]), end=' ')\n    types.add(type(i[1]))\ntypes\nprint(type(dir(In)))", 'help(locals())', '[name for name,thing in inspect.getmembers([])]', '[name for name,thing in A.getmembers([])]', "class A:\n    a = 1\n    def say_something_to(self, b):\n        print('Hi', b)\n        \nprint('A.a =', A.a)\nx = A()\nx.say_something_to('you!')", '[name for name,thing in A.getmembers([])]', 'import inspectct\n[name for name,thing in inspect.getmembers([])]', 'import inspect\n[name for name,thing in inspect.getmembers([])]', 'dir()', 'help(pop)', 'globals()', 'print(globals())'], '_oh': {4: 4456089680, 5: 4456089680, 6: 4456089712, 8: ['In', 'Out', '_', '_4', '_5', '_6', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], 11: <module 'builtins' (built-in)>, 12: {'__name__': 'builtins', '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib. ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., '__IPYTHON__': True, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>, 'dreload': <function _dreload at 0x10b7ce510>}, 13: {...}, 14: {...}, 15: True, 17: ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes'], 18: ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], 19: ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort'], 20: ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_18', '_19', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], 22: <class 'list'>, 23: <class 'list'>, 24: <class 'IPython.core.autocall.ZMQExitAutocall'>, 25: <class 'IPython.core.autocall.ZMQExitAutocall'>, 26: <class 'int'>, 27: <class 'module'>, 28: <class 'module'>, 34: {'_i1', '_26', '_11', '_i4', '__doc__', '_i7', '_sh', '_22', '_i12', '_i19', '_i3', '_i31', '_i26', '_ih', '_14', '_i6', '_19', '_17', '_i13', '_8', '_i14', 'a', '_i24', '_20', '_i29', '_i32', 'quit', '__builtin__', '__builtins__', '_i5', '_i22', '_ii', '_i16', '_i8', '_18', '_i27', '_5', '__loader__', '_23', '_i20', '_15', '_', '_i', '_6', '_12', '_25', '__name__', '_i23', '_i30', '_i33', 'Out', '_dh', '_27', '_i21', 'types', '_28', '_4', '_i25', '_iii', '_i11', '_oh', '_13', '_i18', '_i28', '_24', '__', '__spec__', '_i17', '_i15', '_i34', '_i10', 'get_ipython', '_i2', 'i', 'In', '_i9', '___', '__package__', 'exit'}, 36: {<class 'str'>}, 37: {<class 'str'>}, 38: {<class 'str'>}, 47: {<class 'tuple'>}, 48: {<class 'tuple'>}, 49: {<class 'str'>}, 50: {<class 'str'>}, 51: {<class 'str'>}, 59: ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__i ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., '__IPYTHON__': True, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>, 'dreload': <function _dreload at 0x10b7ce510>}, 13: {...}, 14: {...}, 15: True, 17: ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes'], 18: ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], 19: ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort'], 20: ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_18', '_19', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], 22: <class 'list'>, 23: <class 'list'>, 24: <class 'IPython.core.autocall.ZMQExitAutocall'>, 25: <class 'IPython.core.autocall.ZMQExitAutocall'>, 26: <class 'int'>, 27: <class 'module'>, 28: <class 'module'>, 34: {'_i1', '_26', '_11', '_i4', '__doc__', '_i7', '_sh', '_22', '_i12', '_i19', '_i3', '_i31', '_i26', '_ih', '_14', '_i6', '_19', '_17', '_i13', '_8', '_i14', 'a', '_i24', '_20', '_i29', '_i32', 'quit', '__builtin__', '__builtins__', '_i5', '_i22', '_ii', '_i16', '_i8', '_18', '_i27', '_5', '__loader__', '_23', '_i20', '_15', '_', '_i', '_6', '_12', '_25', '__name__', '_i23', '_i30', '_i33', 'Out', '_dh', '_27', '_i21', 'types', '_28', '_4', '_i25', '_iii', '_i11', '_oh', '_13', '_i18', '_i28', '_24', '__', '__spec__', '_i17', '_i15', '_i34', '_i10', 'get_ipython', '_i2', 'i', 'In', '_i9', '___', '__package__', 'exit'}, 36: {<class 'str'>}, 37: {<class 'str'>}, 38: {<class 'str'>}, 47: {<class 'tuple'>}, 48: {<class 'tuple'>}, 49: {<class 'str'>}, 50: {<class 'str'>}, 51: {<class 'str'>}, 59: ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__i ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., '__IPYTHON__': True, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>, 'dreload': <function _dreload at 0x10b7ce510>}, '_i13': 'globals()', '_13': {...}, '_i14': 'locals()', '_14': {...}, '_i15': 'locals()==globals()', '_15': True, '_i16': 'help(dir)', '_i17': 'dir(a)', '_17': ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes'], '_i18': 'dir()', '_18': ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], '_i19': 'dir(_)', '_19': ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort'], '_i20': 'dir()', '_20': ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_18', '_19', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit'], '_i21': 'print(dir())', '_i22': 'type(_)', '_22': <class 'list'>, '_i23': 'type(In)', '_23': <class 'list'>, '_i24': 'type(quit)', '_24': <class 'IPython.core.autocall.ZMQExitAutocall'>, '_i25': 'type(exit)', '_25': <class 'IPython.core.autocall.ZMQExitAutocall'>, '_i26': 'type(a)', '_26': <class 'int'>, '_i27': 'type(__builtin__)', '_27': <class 'module'>, '_i28': 'type(__builtins__)', '_28': <class 'module'>, '_i29': 'for i in dir():\n    print(i)', 'i': (105, 'types'), '_i30': 'types=()\nfor i in dir():\n    print(i)', 'types': {<class 'str'>}, '_i31': 'types=()\nfor i in dir():\n    types += i', '_i32': 'types=()\nfor i in dir():\n    types.add(i)', '_i33': 'types=set()\nfor i in dir():\n    types.add(i)', '_i34': 'types=set()\nfor i in dir():\n    types.add(i)\ntypes', '_34': {'_i1', '_26', '_11', '_i4', '__doc__', '_i7', '_sh', '_22', '_i12', '_i19', '_i3', '_i31', '_i26', '_ih', '_14', '_i6', '_19', '_17', '_i13', '_8', '_i14', 'a', '_i24', '_20', '_i29', '_i32', 'quit', '__builtin__', '__builtins__', '_i5',  ...

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_11', '_12', '_13', '_14', '_15', '_17', '_18', '_19', '_20', '_4', '_5', '_6', '_8', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', '_sh', 'a', 'exit', 'get_ipython', 'quit']

# %%
types=set()
for i in enumerate(dir()):
    #print(type(i[1]), end=' ')
    types.add(type(i[1]))
types
print(type(dir(In)))
# Out:
# <class 'list'>

# %% [markdown]
# In Python, namespaces are built over dictionaries.

# %% [markdown]
# Namespaces are nested and the outter one is called [the `built-in` namespace](https://docs.python.org/3/library/functions.html).

# %%
__builtin__.__dict__
# Out:
# {'ArithmeticError': ArithmeticError,
#  'AssertionError': AssertionError,
#  'AttributeError': AttributeError,
#  'BaseException': BaseException,
#  'BlockingIOError': BlockingIOError,
#  'BrokenPipeError': BrokenPipeError,
#  'BufferError': BufferError,
#  'BytesWarning': BytesWarning,
#  'ChildProcessError': ChildProcessError,
#  'ConnectionAbortedError': ConnectionAbortedError,
#  'ConnectionError': ConnectionError,
#  'ConnectionRefusedError': ConnectionRefusedError,
#  'ConnectionResetError': ConnectionResetError,
#  'DeprecationWarning': DeprecationWarning,
#  'EOFError': EOFError,
#  'Ellipsis': Ellipsis,
#  'EnvironmentError': OSError,
#  'Exception': Exception,
#  'False': False,
#  'FileExistsError': FileExistsError,
#  'FileNotFoundError': FileNotFoundError,
#  'FloatingPointError': FloatingPointError,
#  'FutureWarning': FutureWarning,
#  'GeneratorExit': GeneratorExit,
#  'IOError': OSError,
#  'ImportError': ImportError,
#  'ImportWarning': ImportWarning,
#  'IndentationError': IndentationError,
#  'IndexError': IndexError,
#  'InterruptedError': InterruptedError,
#  'IsADirectoryError': IsADirectoryError,
#  'KeyError': KeyError,
#  'KeyboardInterrupt': KeyboardInterrupt,
#  'LookupError': LookupError,
#  'MemoryError': MemoryError,
#  'ModuleNotFoundError': ModuleNotFoundError,
#  'NameError': NameError,
#  'None': None,
#  'NotADirectoryError': NotADirectoryError,
#  'NotImplemented': NotImplemented,
#  'NotImplementedError': NotImplementedError,
#  'OSError': OSError,
#  'OverflowError': OverflowError,
#  'PendingDeprecationWarning': PendingDeprecationWarning,
#  'PermissionError': PermissionError,
#  'ProcessLookupError': ProcessLookupError,
#  'RecursionError': RecursionError,
#  'ReferenceError': ReferenceError,
#  'ResourceWarning': ResourceWarning,
#  'RuntimeError': RuntimeError,
#  'RuntimeWarning': RuntimeWarning,
#  'StopAsyncIteration': StopAsyncIteration,
#  'StopIteration': StopIteration,
#  'SyntaxError': SyntaxError,
#  'SyntaxWarning': SyntaxWarning,
#  'SystemError': SystemError,
#  'SystemExit': SystemExit,
#  'TabError': TabError,
#  'TimeoutError': TimeoutError,
#  'True': True,
#  'TypeError': TypeError,
#  'UnboundLocalError': UnboundLocalError,
#  'UnicodeDecodeError': UnicodeDecodeError,
#  'UnicodeEncodeError': UnicodeEncodeError,
#  'UnicodeError': UnicodeError,
#  'UnicodeTranslateError': UnicodeTranslateError,
#  'UnicodeWarning': UnicodeWarning,
#  'UserWarning': UserWarning,
#  'ValueError': ValueError,
#  'Warning': Warning,
#  'ZeroDivisionError': ZeroDivisionError,
#  '__IPYTHON__': True,
#  '__build_class__': <function __build_class__>,
#  '__debug__': True,
#  '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#  '__import__': <function __import__>,
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__name__': 'builtins',
#  '__package__': '',
#  '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#  'abs': <function abs>,
#  'all': <function all>,
#  'any': <function any>,
#  'ascii': <function ascii>,
#  'bin': <function bin>,
#  'bool': bool,
#  'bytearray': bytearray,
#  'bytes': bytes,
#  'callable': <function callable>,
#  'chr': <function chr>,
#  'classmethod': classmethod,
#  'compile': <function compile>,
#  'complex': complex,
#  'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#  All Rights Reserved.
#
#  Copyright (c) 2000 BeOpen.com.
#  All Rights Reserved.
#
#  Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#  All Rights Reserved.
#
#  Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#  All Rights Reserved.,
#  'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#      for supporting Python development.  See www.python.org for more information.,
#  'delattr': <function delattr>,
#  'dict': dict,
#  'dir': <function dir>,
#  'divmod': <function divmod>,
#  'dreload': <function IPython.lib.deepreload._dreload>,
#  'enumerate': enumerate,
#  'eval': <function eval>,
#  'exec': <function exec>,
#  'filter': filter,
#  'float': float,
#  'format': <function format>,
#  'frozenset': frozenset,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#  'getattr': <function getattr>,
#  'globals': <function globals>,
#  'hasattr': <function hasattr>,
#  'hash': <function hash>,
#  'help': Type help() for interactive help, or help(object) for help about object.,
#  'hex': <function hex>,
#  'id': <function id>,
#  'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#  'int': int,
#  'isinstance': <function isinstance>,
#  'issubclass': <function issubclass>,
#  'iter': <function iter>,
#  'len': <function len>,
#  'license': Type license() to see the full license text,
#  'list': list,
#  'locals': <function locals>,
#  'map': map,
#  'max': <function max>,
#  'memoryview': memoryview,
#  'min': <function min>,
#  'next': <function next>,
#  'object': object,
#  'oct': <function oct>,
#  'open': <function io.open>,
#  'ord': <function ord>,
#  'pow': <function pow>,
#  'print': <function print>,
#  'property': property,
#  'range': range,
#  'repr': <function repr>,
#  'reversed': reversed,
#  'round': <function round>,
#  'set': set,
#  'setattr': <function setattr>,
#  'slice': slice,
#  'sorted': <function sorted>,
#  'staticmethod': staticmethod,
#  'str': str,
#  'sum': <function sum>,
#  'super': super,
#  'tuple': tuple,
#  'type': type,
#  'vars': <function vars>,
#  'zip': zip}

# %%
globals()
# Out:
# {'In': ['',
#   'a=1\nprint(def(a), def(1))',
#   'a=1\nprint(id(a), id(1))',
#   'print(id(1))',
#   'id(1)',
#   'a=1\nid(a)',
#   'id(2)',
#   'A *namespace* is a collection of names:',
#   'dir()',
#   '.__dict__',
#   '__dict__',
#   '__builtin__',
#   '__builtin__.__dict__',
#   'globals()'],
#  'Out': {4: 4456089680,
#   5: 4456089680,
#   6: 4456089712,
#   8: ['In',
#    'Out',
#    '_',
#    '_4',
#    '_5',
#    '_6',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_sh',
#    'a',
#    'exit',
#    'get_ipython',
#    'quit'],
#   11: <module 'builtins' (built-in)>,
#   12: {'ArithmeticError': ArithmeticError,
#    'AssertionError': AssertionError,
#    'AttributeError': AttributeError,
#    'BaseException': BaseException,
#    'BlockingIOError': BlockingIOError,
#    'BrokenPipeError': BrokenPipeError,
#    'BufferError': BufferError,
#    'BytesWarning': BytesWarning,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionError': ConnectionError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'DeprecationWarning': DeprecationWarning,
#    'EOFError': EOFError,
#    'Ellipsis': Ellipsis,
#    'EnvironmentError': OSError,
#    'Exception': Exception,
#    'False': False,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'FloatingPointError': FloatingPointError,
#    'FutureWarning': FutureWarning,
#    'GeneratorExit': GeneratorExit,
#    'IOError': OSError,
#    'ImportError': ImportError,
#    'ImportWarning': ImportWarning,
#    'IndentationError': IndentationError,
#    'IndexError': IndexError,
#    'InterruptedError': InterruptedError,
#    'IsADirectoryError': IsADirectoryError,
#    'KeyError': KeyError,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'LookupError': LookupError,
#    'MemoryError': MemoryError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'NameError': NameError,
#    'None': None,
#    'NotADirectoryError': NotADirectoryError,
#    'NotImplemented': NotImplemented,
#    'NotImplementedError': NotImplementedError,
#    'OSError': OSError,
#    'OverflowError': OverflowError,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'RecursionError': RecursionError,
#    'ReferenceError': ReferenceError,
#    'ResourceWarning': ResourceWarning,
#    'RuntimeError': RuntimeError,
#    'RuntimeWarning': RuntimeWarning,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'SyntaxError': SyntaxError,
#    'SyntaxWarning': SyntaxWarning,
#    'SystemError': SystemError,
#    'SystemExit': SystemExit,
#    'TabError': TabError,
#    'TimeoutError': TimeoutError,
#    'True': True,
#    'TypeError': TypeError,
#    'UnboundLocalError': UnboundLocalError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeError': UnicodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'UnicodeWarning': UnicodeWarning,
#    'UserWarning': UserWarning,
#    'ValueError': ValueError,
#    'Warning': Warning,
#    'ZeroDivisionError': ZeroDivisionError,
#    '__IPYTHON__': True,
#    '__build_class__': <function __build_class__>,
#    '__debug__': True,
#    '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#    '__import__': <function __import__>,
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__name__': 'builtins',
#    '__package__': '',
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#    'abs': <function abs>,
#    'all': <function all>,
#    'any': <function any>,
#    'ascii': <function ascii>,
#    'bin': <function bin>,
#    'bool': bool,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'callable': <function callable>,
#    'chr': <function chr>,
#    'classmethod': classmethod,
#    'compile': <function compile>,
#    'complex': complex,
#    'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#        for supporting Python development.  See www.python.org for more information.,
#    'delattr': <function delattr>,
#    'dict': dict,
#    'dir': <function dir>,
#    'divmod': <function divmod>,
#    'dreload': <function IPython.lib.deepreload._dreload>,
#    'enumerate': enumerate,
#    'eval': <function eval>,
#    'exec': <function exec>,
#    'filter': filter,
#    'float': float,
#    'format': <function format>,
#    'frozenset': frozenset,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#    'getattr': <function getattr>,
#    'globals': <function globals>,
#    'hasattr': <function hasattr>,
#    'hash': <function hash>,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    'hex': <function hex>,
#    'id': <function id>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#    'int': int,
#    'isinstance': <function isinstance>,
#    'issubclass': <function issubclass>,
#    'iter': <function iter>,
#    'len': <function len>,
#    'license': Type license() to see the full license text,
#    'list': list,
#    'locals': <function locals>,
#    'map': map,
#    'max': <function max>,
#    'memoryview': memoryview,
#    'min': <function min>,
#    'next': <function next>,
#    'object': object,
#    'oct': <function oct>,
#    'open': <function io.open>,
#    'ord': <function ord>,
#    'pow': <function pow>,
#    'print': <function print>,
#    'property': property,
#    'range': range,
#    'repr': <function repr>,
#    'reversed': reversed,
#    'round': <function round>,
#    'set': set,
#    'setattr': <function setattr>,
#    'slice': slice,
#    'sorted': <function sorted>,
#    'staticmethod': staticmethod,
#    'str': str,
#    'sum': <function sum>,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'vars': <function vars>,
#    'zip': zip}},
#  '_': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'BufferError': BufferError,
#   'BytesWarning': BytesWarning,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionError': ConnectionError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'DeprecationWarning': DeprecationWarning,
#   'EOFError': EOFError,
#   'Ellipsis': Ellipsis,
#   'EnvironmentError': OSError,
#   'Exception': Exception,
#   'False': False,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'FloatingPointError': FloatingPointError,
#   'FutureWarning': FutureWarning,
#   'GeneratorExit': GeneratorExit,
#   'IOError': OSError,
#   'ImportError': ImportError,
#   'ImportWarning': ImportWarning,
#   'IndentationError': IndentationError,
#   'IndexError': IndexError,
#   'InterruptedError': InterruptedError,
#   'IsADirectoryError': IsADirectoryError,
#   'KeyError': KeyError,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'LookupError': LookupError,
#   'MemoryError': MemoryError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'NameError': NameError,
#   'None': None,
#   'NotADirectoryError': NotADirectoryError,
#   'NotImplemented': NotImplemented,
#   'NotImplementedError': NotImplementedError,
#   'OSError': OSError,
#   'OverflowError': OverflowError,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'RecursionError': RecursionError,
#   'ReferenceError': ReferenceError,
#   'ResourceWarning': ResourceWarning,
#   'RuntimeError': RuntimeError,
#   'RuntimeWarning': RuntimeWarning,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'SyntaxError': SyntaxError,
#   'SyntaxWarning': SyntaxWarning,
#   'SystemError': SystemError,
#   'SystemExit': SystemExit,
#   'TabError': TabError,
#   'TimeoutError': TimeoutError,
#   'True': True,
#   'TypeError': TypeError,
#   'UnboundLocalError': UnboundLocalError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeError': UnicodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'UnicodeWarning': UnicodeWarning,
#   'UserWarning': UserWarning,
#   'ValueError': ValueError,
#   'Warning': Warning,
#   'ZeroDivisionError': ZeroDivisionError,
#   '__IPYTHON__': True,
#   '__build_class__': <function __build_class__>,
#   '__debug__': True,
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__import__': <function __import__>,
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__name__': 'builtins',
#   '__package__': '',
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   'abs': <function abs>,
#   'all': <function all>,
#   'any': <function any>,
#   'ascii': <function ascii>,
#   'bin': <function bin>,
#   'bool': bool,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'callable': <function callable>,
#   'chr': <function chr>,
#   'classmethod': classmethod,
#   'compile': <function compile>,
#   'complex': complex,
#   'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'delattr': <function delattr>,
#   'dict': dict,
#   'dir': <function dir>,
#   'divmod': <function divmod>,
#   'dreload': <function IPython.lib.deepreload._dreload>,
#   'enumerate': enumerate,
#   'eval': <function eval>,
#   'exec': <function exec>,
#   'filter': filter,
#   'float': float,
#   'format': <function format>,
#   'frozenset': frozenset,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#   'getattr': <function getattr>,
#   'globals': <function globals>,
#   'hasattr': <function hasattr>,
#   'hash': <function hash>,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   'hex': <function hex>,
#   'id': <function id>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#   'int': int,
#   'isinstance': <function isinstance>,
#   'issubclass': <function issubclass>,
#   'iter': <function iter>,
#   'len': <function len>,
#   'license': Type license() to see the full license text,
#   'list': list,
#   'locals': <function locals>,
#   'map': map,
#   'max': <function max>,
#   'memoryview': memoryview,
#   'min': <function min>,
#   'next': <function next>,
#   'object': object,
#   'oct': <function oct>,
#   'open': <function io.open>,
#   'ord': <function ord>,
#   'pow': <function pow>,
#   'print': <function print>,
#   'property': property,
#   'range': range,
#   'repr': <function repr>,
#   'reversed': reversed,
#   'round': <function round>,
#   'set': set,
#   'setattr': <function setattr>,
#   'slice': slice,
#   'sorted': <function sorted>,
#   'staticmethod': staticmethod,
#   'str': str,
#   'sum': <function sum>,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'vars': <function vars>,
#   'zip': zip},
#  '_11': <module 'builtins' (built-in)>,
#  '_12': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'BufferError': BufferError,
#   'BytesWarning': BytesWarning,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionError': ConnectionError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'DeprecationWarning': DeprecationWarning,
#   'EOFError': EOFError,
#   'Ellipsis': Ellipsis,
#   'EnvironmentError': OSError,
#   'Exception': Exception,
#   'False': False,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'FloatingPointError': FloatingPointError,
#   'FutureWarning': FutureWarning,
#   'GeneratorExit': GeneratorExit,
#   'IOError': OSError,
#   'ImportError': ImportError,
#   'ImportWarning': ImportWarning,
#   'IndentationError': IndentationError,
#   'IndexError': IndexError,
#   'InterruptedError': InterruptedError,
#   'IsADirectoryError': IsADirectoryError,
#   'KeyError': KeyError,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'LookupError': LookupError,
#   'MemoryError': MemoryError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'NameError': NameError,
#   'None': None,
#   'NotADirectoryError': NotADirectoryError,
#   'NotImplemented': NotImplemented,
#   'NotImplementedError': NotImplementedError,
#   'OSError': OSError,
#   'OverflowError': OverflowError,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'RecursionError': RecursionError,
#   'ReferenceError': ReferenceError,
#   'ResourceWarning': ResourceWarning,
#   'RuntimeError': RuntimeError,
#   'RuntimeWarning': RuntimeWarning,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'SyntaxError': SyntaxError,
#   'SyntaxWarning': SyntaxWarning,
#   'SystemError': SystemError,
#   'SystemExit': SystemExit,
#   'TabError': TabError,
#   'TimeoutError': TimeoutError,
#   'True': True,
#   'TypeError': TypeError,
#   'UnboundLocalError': UnboundLocalError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeError': UnicodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'UnicodeWarning': UnicodeWarning,
#   'UserWarning': UserWarning,
#   'ValueError': ValueError,
#   'Warning': Warning,
#   'ZeroDivisionError': ZeroDivisionError,
#   '__IPYTHON__': True,
#   '__build_class__': <function __build_class__>,
#   '__debug__': True,
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__import__': <function __import__>,
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__name__': 'builtins',
#   '__package__': '',
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   'abs': <function abs>,
#   'all': <function all>,
#   'any': <function any>,
#   'ascii': <function ascii>,
#   'bin': <function bin>,
#   'bool': bool,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'callable': <function callable>,
#   'chr': <function chr>,
#   'classmethod': classmethod,
#   'compile': <function compile>,
#   'complex': complex,
#   'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'delattr': <function delattr>,
#   'dict': dict,
#   'dir': <function dir>,
#   'divmod': <function divmod>,
#   'dreload': <function IPython.lib.deepreload._dreload>,
#   'enumerate': enumerate,
#   'eval': <function eval>,
#   'exec': <function exec>,
#   'filter': filter,
#   'float': float,
#   'format': <function format>,
#   'frozenset': frozenset,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#   'getattr': <function getattr>,
#   'globals': <function globals>,
#   'hasattr': <function hasattr>,
#   'hash': <function hash>,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   'hex': <function hex>,
#   'id': <function id>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#   'int': int,
#   'isinstance': <function isinstance>,
#   'issubclass': <function issubclass>,
#   'iter': <function iter>,
#   'len': <function len>,
#   'license': Type license() to see the full license text,
#   'list': list,
#   'locals': <function locals>,
#   'map': map,
#   'max': <function max>,
#   'memoryview': memoryview,
#   'min': <function min>,
#   'next': <function next>,
#   'object': object,
#   'oct': <function oct>,
#   'open': <function io.open>,
#   'ord': <function ord>,
#   'pow': <function pow>,
#   'print': <function print>,
#   'property': property,
#   'range': range,
#   'repr': <function repr>,
#   'reversed': reversed,
#   'round': <function round>,
#   'set': set,
#   'setattr': <function setattr>,
#   'slice': slice,
#   'sorted': <function sorted>,
#   'staticmethod': staticmethod,
#   'str': str,
#   'sum': <function sum>,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'vars': <function vars>,
#   'zip': zip},
#  '_4': 4456089680,
#  '_5': 4456089680,
#  '_6': 4456089712,
#  '_8': ['In',
#   'Out',
#   '_',
#   '_4',
#   '_5',
#   '_6',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_sh',
#   'a',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '__': <module 'builtins' (built-in)>,
#  '___': ['In',
#   'Out',
#   '_',
#   '_4',
#   '_5',
#   '_6',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_sh',
#   'a',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/Users/vruiz/YAPT'],
#  '_i': '__builtin__.__dict__',
#  '_i1': 'a=1\nprint(def(a), def(1))',
#  '_i10': '__dict__',
#  '_i11': '__builtin__',
#  '_i12': '__builtin__.__dict__',
#  '_i13': 'globals()',
#  '_i2': 'a=1\nprint(id(a), id(1))',
#  '_i3': 'print(id(1))',
#  '_i4': 'id(1)',
#  '_i5': 'a=1\nid(a)',
#  '_i6': 'id(2)',
#  '_i7': 'A *namespace* is a collection of names:',
#  '_i8': 'dir()',
#  '_i9': '.__dict__',
#  '_ih': ['',
#   'a=1\nprint(def(a), def(1))',
#   'a=1\nprint(id(a), id(1))',
#   'print(id(1))',
#   'id(1)',
#   'a=1\nid(a)',
#   'id(2)',
#   'A *namespace* is a collection of names:',
#   'dir()',
#   '.__dict__',
#   '__dict__',
#   '__builtin__',
#   '__builtin__.__dict__',
#   'globals()'],
#  '_ii': '__builtin__',
#  '_iii': '__dict__',
#  '_oh': {4: 4456089680,
#   5: 4456089680,
#   6: 4456089712,
#   8: ['In',
#    'Out',
#    '_',
#    '_4',
#    '_5',
#    '_6',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_sh',
#    'a',
#    'exit',
#    'get_ipython',
#    'quit'],
#   11: <module 'builtins' (built-in)>,
#   12: {'ArithmeticError': ArithmeticError,
#    'AssertionError': AssertionError,
#    'AttributeError': AttributeError,
#    'BaseException': BaseException,
#    'BlockingIOError': BlockingIOError,
#    'BrokenPipeError': BrokenPipeError,
#    'BufferError': BufferError,
#    'BytesWarning': BytesWarning,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionError': ConnectionError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'DeprecationWarning': DeprecationWarning,
#    'EOFError': EOFError,
#    'Ellipsis': Ellipsis,
#    'EnvironmentError': OSError,
#    'Exception': Exception,
#    'False': False,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'FloatingPointError': FloatingPointError,
#    'FutureWarning': FutureWarning,
#    'GeneratorExit': GeneratorExit,
#    'IOError': OSError,
#    'ImportError': ImportError,
#    'ImportWarning': ImportWarning,
#    'IndentationError': IndentationError,
#    'IndexError': IndexError,
#    'InterruptedError': InterruptedError,
#    'IsADirectoryError': IsADirectoryError,
#    'KeyError': KeyError,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'LookupError': LookupError,
#    'MemoryError': MemoryError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'NameError': NameError,
#    'None': None,
#    'NotADirectoryError': NotADirectoryError,
#    'NotImplemented': NotImplemented,
#    'NotImplementedError': NotImplementedError,
#    'OSError': OSError,
#    'OverflowError': OverflowError,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'RecursionError': RecursionError,
#    'ReferenceError': ReferenceError,
#    'ResourceWarning': ResourceWarning,
#    'RuntimeError': RuntimeError,
#    'RuntimeWarning': RuntimeWarning,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'SyntaxError': SyntaxError,
#    'SyntaxWarning': SyntaxWarning,
#    'SystemError': SystemError,
#    'SystemExit': SystemExit,
#    'TabError': TabError,
#    'TimeoutError': TimeoutError,
#    'True': True,
#    'TypeError': TypeError,
#    'UnboundLocalError': UnboundLocalError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeError': UnicodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'UnicodeWarning': UnicodeWarning,
#    'UserWarning': UserWarning,
#    'ValueError': ValueError,
#    'Warning': Warning,
#    'ZeroDivisionError': ZeroDivisionError,
#    '__IPYTHON__': True,
#    '__build_class__': <function __build_class__>,
#    '__debug__': True,
#    '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#    '__import__': <function __import__>,
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__name__': 'builtins',
#    '__package__': '',
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#    'abs': <function abs>,
#    'all': <function all>,
#    'any': <function any>,
#    'ascii': <function ascii>,
#    'bin': <function bin>,
#    'bool': bool,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'callable': <function callable>,
#    'chr': <function chr>,
#    'classmethod': classmethod,
#    'compile': <function compile>,
#    'complex': complex,
#    'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#        for supporting Python development.  See www.python.org for more information.,
#    'delattr': <function delattr>,
#    'dict': dict,
#    'dir': <function dir>,
#    'divmod': <function divmod>,
#    'dreload': <function IPython.lib.deepreload._dreload>,
#    'enumerate': enumerate,
#    'eval': <function eval>,
#    'exec': <function exec>,
#    'filter': filter,
#    'float': float,
#    'format': <function format>,
#    'frozenset': frozenset,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#    'getattr': <function getattr>,
#    'globals': <function globals>,
#    'hasattr': <function hasattr>,
#    'hash': <function hash>,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    'hex': <function hex>,
#    'id': <function id>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#    'int': int,
#    'isinstance': <function isinstance>,
#    'issubclass': <function issubclass>,
#    'iter': <function iter>,
#    'len': <function len>,
#    'license': Type license() to see the full license text,
#    'list': list,
#    'locals': <function locals>,
#    'map': map,
#    'max': <function max>,
#    'memoryview': memoryview,
#    'min': <function min>,
#    'next': <function next>,
#    'object': object,
#    'oct': <function oct>,
#    'open': <function io.open>,
#    'ord': <function ord>,
#    'pow': <function pow>,
#    'print': <function print>,
#    'property': property,
#    'range': range,
#    'repr': <function repr>,
#    'reversed': reversed,
#    'round': <function round>,
#    'set': set,
#    'setattr': <function setattr>,
#    'slice': slice,
#    'sorted': <function sorted>,
#    'staticmethod': staticmethod,
#    'str': str,
#    'sum': <function sum>,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'vars': <function vars>,
#    'zip': zip}},
#  '_sh': <module 'IPython.core.shadowns' from '/usr/local/lib/python3.6/site-packages/IPython/core/shadowns.py'>,
#  'a': 1,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10b7d36a0>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10b7d36a0>}

# %%
locals()
# Out:
# {'In': ['',
#   'a=1\nprint(def(a), def(1))',
#   'a=1\nprint(id(a), id(1))',
#   'print(id(1))',
#   'id(1)',
#   'a=1\nid(a)',
#   'id(2)',
#   'A *namespace* is a collection of names:',
#   'dir()',
#   '.__dict__',
#   '__dict__',
#   '__builtin__',
#   '__builtin__.__dict__',
#   'globals()',
#   'locals()'],
#  'Out': {4: 4456089680,
#   5: 4456089680,
#   6: 4456089712,
#   8: ['In',
#    'Out',
#    '_',
#    '_4',
#    '_5',
#    '_6',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_sh',
#    'a',
#    'exit',
#    'get_ipython',
#    'quit'],
#   11: <module 'builtins' (built-in)>,
#   12: {'ArithmeticError': ArithmeticError,
#    'AssertionError': AssertionError,
#    'AttributeError': AttributeError,
#    'BaseException': BaseException,
#    'BlockingIOError': BlockingIOError,
#    'BrokenPipeError': BrokenPipeError,
#    'BufferError': BufferError,
#    'BytesWarning': BytesWarning,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionError': ConnectionError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'DeprecationWarning': DeprecationWarning,
#    'EOFError': EOFError,
#    'Ellipsis': Ellipsis,
#    'EnvironmentError': OSError,
#    'Exception': Exception,
#    'False': False,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'FloatingPointError': FloatingPointError,
#    'FutureWarning': FutureWarning,
#    'GeneratorExit': GeneratorExit,
#    'IOError': OSError,
#    'ImportError': ImportError,
#    'ImportWarning': ImportWarning,
#    'IndentationError': IndentationError,
#    'IndexError': IndexError,
#    'InterruptedError': InterruptedError,
#    'IsADirectoryError': IsADirectoryError,
#    'KeyError': KeyError,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'LookupError': LookupError,
#    'MemoryError': MemoryError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'NameError': NameError,
#    'None': None,
#    'NotADirectoryError': NotADirectoryError,
#    'NotImplemented': NotImplemented,
#    'NotImplementedError': NotImplementedError,
#    'OSError': OSError,
#    'OverflowError': OverflowError,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'RecursionError': RecursionError,
#    'ReferenceError': ReferenceError,
#    'ResourceWarning': ResourceWarning,
#    'RuntimeError': RuntimeError,
#    'RuntimeWarning': RuntimeWarning,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'SyntaxError': SyntaxError,
#    'SyntaxWarning': SyntaxWarning,
#    'SystemError': SystemError,
#    'SystemExit': SystemExit,
#    'TabError': TabError,
#    'TimeoutError': TimeoutError,
#    'True': True,
#    'TypeError': TypeError,
#    'UnboundLocalError': UnboundLocalError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeError': UnicodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'UnicodeWarning': UnicodeWarning,
#    'UserWarning': UserWarning,
#    'ValueError': ValueError,
#    'Warning': Warning,
#    'ZeroDivisionError': ZeroDivisionError,
#    '__IPYTHON__': True,
#    '__build_class__': <function __build_class__>,
#    '__debug__': True,
#    '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#    '__import__': <function __import__>,
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__name__': 'builtins',
#    '__package__': '',
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#    'abs': <function abs>,
#    'all': <function all>,
#    'any': <function any>,
#    'ascii': <function ascii>,
#    'bin': <function bin>,
#    'bool': bool,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'callable': <function callable>,
#    'chr': <function chr>,
#    'classmethod': classmethod,
#    'compile': <function compile>,
#    'complex': complex,
#    'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#        for supporting Python development.  See www.python.org for more information.,
#    'delattr': <function delattr>,
#    'dict': dict,
#    'dir': <function dir>,
#    'divmod': <function divmod>,
#    'dreload': <function IPython.lib.deepreload._dreload>,
#    'enumerate': enumerate,
#    'eval': <function eval>,
#    'exec': <function exec>,
#    'filter': filter,
#    'float': float,
#    'format': <function format>,
#    'frozenset': frozenset,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#    'getattr': <function getattr>,
#    'globals': <function globals>,
#    'hasattr': <function hasattr>,
#    'hash': <function hash>,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    'hex': <function hex>,
#    'id': <function id>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#    'int': int,
#    'isinstance': <function isinstance>,
#    'issubclass': <function issubclass>,
#    'iter': <function iter>,
#    'len': <function len>,
#    'license': Type license() to see the full license text,
#    'list': list,
#    'locals': <function locals>,
#    'map': map,
#    'max': <function max>,
#    'memoryview': memoryview,
#    'min': <function min>,
#    'next': <function next>,
#    'object': object,
#    'oct': <function oct>,
#    'open': <function io.open>,
#    'ord': <function ord>,
#    'pow': <function pow>,
#    'print': <function print>,
#    'property': property,
#    'range': range,
#    'repr': <function repr>,
#    'reversed': reversed,
#    'round': <function round>,
#    'set': set,
#    'setattr': <function setattr>,
#    'slice': slice,
#    'sorted': <function sorted>,
#    'staticmethod': staticmethod,
#    'str': str,
#    'sum': <function sum>,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'vars': <function vars>,
#    'zip': zip},
#   13: {...}},
#  '_': {...},
#  '_11': <module 'builtins' (built-in)>,
#  '_12': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'BufferError': BufferError,
#   'BytesWarning': BytesWarning,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionError': ConnectionError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'DeprecationWarning': DeprecationWarning,
#   'EOFError': EOFError,
#   'Ellipsis': Ellipsis,
#   'EnvironmentError': OSError,
#   'Exception': Exception,
#   'False': False,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'FloatingPointError': FloatingPointError,
#   'FutureWarning': FutureWarning,
#   'GeneratorExit': GeneratorExit,
#   'IOError': OSError,
#   'ImportError': ImportError,
#   'ImportWarning': ImportWarning,
#   'IndentationError': IndentationError,
#   'IndexError': IndexError,
#   'InterruptedError': InterruptedError,
#   'IsADirectoryError': IsADirectoryError,
#   'KeyError': KeyError,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'LookupError': LookupError,
#   'MemoryError': MemoryError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'NameError': NameError,
#   'None': None,
#   'NotADirectoryError': NotADirectoryError,
#   'NotImplemented': NotImplemented,
#   'NotImplementedError': NotImplementedError,
#   'OSError': OSError,
#   'OverflowError': OverflowError,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'RecursionError': RecursionError,
#   'ReferenceError': ReferenceError,
#   'ResourceWarning': ResourceWarning,
#   'RuntimeError': RuntimeError,
#   'RuntimeWarning': RuntimeWarning,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'SyntaxError': SyntaxError,
#   'SyntaxWarning': SyntaxWarning,
#   'SystemError': SystemError,
#   'SystemExit': SystemExit,
#   'TabError': TabError,
#   'TimeoutError': TimeoutError,
#   'True': True,
#   'TypeError': TypeError,
#   'UnboundLocalError': UnboundLocalError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeError': UnicodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'UnicodeWarning': UnicodeWarning,
#   'UserWarning': UserWarning,
#   'ValueError': ValueError,
#   'Warning': Warning,
#   'ZeroDivisionError': ZeroDivisionError,
#   '__IPYTHON__': True,
#   '__build_class__': <function __build_class__>,
#   '__debug__': True,
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__import__': <function __import__>,
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__name__': 'builtins',
#   '__package__': '',
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   'abs': <function abs>,
#   'all': <function all>,
#   'any': <function any>,
#   'ascii': <function ascii>,
#   'bin': <function bin>,
#   'bool': bool,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'callable': <function callable>,
#   'chr': <function chr>,
#   'classmethod': classmethod,
#   'compile': <function compile>,
#   'complex': complex,
#   'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'delattr': <function delattr>,
#   'dict': dict,
#   'dir': <function dir>,
#   'divmod': <function divmod>,
#   'dreload': <function IPython.lib.deepreload._dreload>,
#   'enumerate': enumerate,
#   'eval': <function eval>,
#   'exec': <function exec>,
#   'filter': filter,
#   'float': float,
#   'format': <function format>,
#   'frozenset': frozenset,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#   'getattr': <function getattr>,
#   'globals': <function globals>,
#   'hasattr': <function hasattr>,
#   'hash': <function hash>,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   'hex': <function hex>,
#   'id': <function id>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#   'int': int,
#   'isinstance': <function isinstance>,
#   'issubclass': <function issubclass>,
#   'iter': <function iter>,
#   'len': <function len>,
#   'license': Type license() to see the full license text,
#   'list': list,
#   'locals': <function locals>,
#   'map': map,
#   'max': <function max>,
#   'memoryview': memoryview,
#   'min': <function min>,
#   'next': <function next>,
#   'object': object,
#   'oct': <function oct>,
#   'open': <function io.open>,
#   'ord': <function ord>,
#   'pow': <function pow>,
#   'print': <function print>,
#   'property': property,
#   'range': range,
#   'repr': <function repr>,
#   'reversed': reversed,
#   'round': <function round>,
#   'set': set,
#   'setattr': <function setattr>,
#   'slice': slice,
#   'sorted': <function sorted>,
#   'staticmethod': staticmethod,
#   'str': str,
#   'sum': <function sum>,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'vars': <function vars>,
#   'zip': zip},
#  '_13': {...},
#  '_4': 4456089680,
#  '_5': 4456089680,
#  '_6': 4456089712,
#  '_8': ['In',
#   'Out',
#   '_',
#   '_4',
#   '_5',
#   '_6',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_sh',
#   'a',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '__': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'BufferError': BufferError,
#   'BytesWarning': BytesWarning,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionError': ConnectionError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'DeprecationWarning': DeprecationWarning,
#   'EOFError': EOFError,
#   'Ellipsis': Ellipsis,
#   'EnvironmentError': OSError,
#   'Exception': Exception,
#   'False': False,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'FloatingPointError': FloatingPointError,
#   'FutureWarning': FutureWarning,
#   'GeneratorExit': GeneratorExit,
#   'IOError': OSError,
#   'ImportError': ImportError,
#   'ImportWarning': ImportWarning,
#   'IndentationError': IndentationError,
#   'IndexError': IndexError,
#   'InterruptedError': InterruptedError,
#   'IsADirectoryError': IsADirectoryError,
#   'KeyError': KeyError,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'LookupError': LookupError,
#   'MemoryError': MemoryError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'NameError': NameError,
#   'None': None,
#   'NotADirectoryError': NotADirectoryError,
#   'NotImplemented': NotImplemented,
#   'NotImplementedError': NotImplementedError,
#   'OSError': OSError,
#   'OverflowError': OverflowError,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'RecursionError': RecursionError,
#   'ReferenceError': ReferenceError,
#   'ResourceWarning': ResourceWarning,
#   'RuntimeError': RuntimeError,
#   'RuntimeWarning': RuntimeWarning,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'SyntaxError': SyntaxError,
#   'SyntaxWarning': SyntaxWarning,
#   'SystemError': SystemError,
#   'SystemExit': SystemExit,
#   'TabError': TabError,
#   'TimeoutError': TimeoutError,
#   'True': True,
#   'TypeError': TypeError,
#   'UnboundLocalError': UnboundLocalError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeError': UnicodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'UnicodeWarning': UnicodeWarning,
#   'UserWarning': UserWarning,
#   'ValueError': ValueError,
#   'Warning': Warning,
#   'ZeroDivisionError': ZeroDivisionError,
#   '__IPYTHON__': True,
#   '__build_class__': <function __build_class__>,
#   '__debug__': True,
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__import__': <function __import__>,
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__name__': 'builtins',
#   '__package__': '',
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   'abs': <function abs>,
#   'all': <function all>,
#   'any': <function any>,
#   'ascii': <function ascii>,
#   'bin': <function bin>,
#   'bool': bool,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'callable': <function callable>,
#   'chr': <function chr>,
#   'classmethod': classmethod,
#   'compile': <function compile>,
#   'complex': complex,
#   'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'delattr': <function delattr>,
#   'dict': dict,
#   'dir': <function dir>,
#   'divmod': <function divmod>,
#   'dreload': <function IPython.lib.deepreload._dreload>,
#   'enumerate': enumerate,
#   'eval': <function eval>,
#   'exec': <function exec>,
#   'filter': filter,
#   'float': float,
#   'format': <function format>,
#   'frozenset': frozenset,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#   'getattr': <function getattr>,
#   'globals': <function globals>,
#   'hasattr': <function hasattr>,
#   'hash': <function hash>,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   'hex': <function hex>,
#   'id': <function id>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#   'int': int,
#   'isinstance': <function isinstance>,
#   'issubclass': <function issubclass>,
#   'iter': <function iter>,
#   'len': <function len>,
#   'license': Type license() to see the full license text,
#   'list': list,
#   'locals': <function locals>,
#   'map': map,
#   'max': <function max>,
#   'memoryview': memoryview,
#   'min': <function min>,
#   'next': <function next>,
#   'object': object,
#   'oct': <function oct>,
#   'open': <function io.open>,
#   'ord': <function ord>,
#   'pow': <function pow>,
#   'print': <function print>,
#   'property': property,
#   'range': range,
#   'repr': <function repr>,
#   'reversed': reversed,
#   'round': <function round>,
#   'set': set,
#   'setattr': <function setattr>,
#   'slice': slice,
#   'sorted': <function sorted>,
#   'staticmethod': staticmethod,
#   'str': str,
#   'sum': <function sum>,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'vars': <function vars>,
#   'zip': zip},
#  '___': <module 'builtins' (built-in)>,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/Users/vruiz/YAPT'],
#  '_i': 'globals()',
#  '_i1': 'a=1\nprint(def(a), def(1))',
#  '_i10': '__dict__',
#  '_i11': '__builtin__',
#  '_i12': '__builtin__.__dict__',
#  '_i13': 'globals()',
#  '_i14': 'locals()',
#  '_i2': 'a=1\nprint(id(a), id(1))',
#  '_i3': 'print(id(1))',
#  '_i4': 'id(1)',
#  '_i5': 'a=1\nid(a)',
#  '_i6': 'id(2)',
#  '_i7': 'A *namespace* is a collection of names:',
#  '_i8': 'dir()',
#  '_i9': '.__dict__',
#  '_ih': ['',
#   'a=1\nprint(def(a), def(1))',
#   'a=1\nprint(id(a), id(1))',
#   'print(id(1))',
#   'id(1)',
#   'a=1\nid(a)',
#   'id(2)',
#   'A *namespace* is a collection of names:',
#   'dir()',
#   '.__dict__',
#   '__dict__',
#   '__builtin__',
#   '__builtin__.__dict__',
#   'globals()',
#   'locals()'],
#  '_ii': '__builtin__.__dict__',
#  '_iii': '__builtin__',
#  '_oh': {4: 4456089680,
#   5: 4456089680,
#   6: 4456089712,
#   8: ['In',
#    'Out',
#    '_',
#    '_4',
#    '_5',
#    '_6',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_sh',
#    'a',
#    'exit',
#    'get_ipython',
#    'quit'],
#   11: <module 'builtins' (built-in)>,
#   12: {'ArithmeticError': ArithmeticError,
#    'AssertionError': AssertionError,
#    'AttributeError': AttributeError,
#    'BaseException': BaseException,
#    'BlockingIOError': BlockingIOError,
#    'BrokenPipeError': BrokenPipeError,
#    'BufferError': BufferError,
#    'BytesWarning': BytesWarning,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionError': ConnectionError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'DeprecationWarning': DeprecationWarning,
#    'EOFError': EOFError,
#    'Ellipsis': Ellipsis,
#    'EnvironmentError': OSError,
#    'Exception': Exception,
#    'False': False,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'FloatingPointError': FloatingPointError,
#    'FutureWarning': FutureWarning,
#    'GeneratorExit': GeneratorExit,
#    'IOError': OSError,
#    'ImportError': ImportError,
#    'ImportWarning': ImportWarning,
#    'IndentationError': IndentationError,
#    'IndexError': IndexError,
#    'InterruptedError': InterruptedError,
#    'IsADirectoryError': IsADirectoryError,
#    'KeyError': KeyError,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'LookupError': LookupError,
#    'MemoryError': MemoryError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'NameError': NameError,
#    'None': None,
#    'NotADirectoryError': NotADirectoryError,
#    'NotImplemented': NotImplemented,
#    'NotImplementedError': NotImplementedError,
#    'OSError': OSError,
#    'OverflowError': OverflowError,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'RecursionError': RecursionError,
#    'ReferenceError': ReferenceError,
#    'ResourceWarning': ResourceWarning,
#    'RuntimeError': RuntimeError,
#    'RuntimeWarning': RuntimeWarning,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'SyntaxError': SyntaxError,
#    'SyntaxWarning': SyntaxWarning,
#    'SystemError': SystemError,
#    'SystemExit': SystemExit,
#    'TabError': TabError,
#    'TimeoutError': TimeoutError,
#    'True': True,
#    'TypeError': TypeError,
#    'UnboundLocalError': UnboundLocalError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeError': UnicodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'UnicodeWarning': UnicodeWarning,
#    'UserWarning': UserWarning,
#    'ValueError': ValueError,
#    'Warning': Warning,
#    'ZeroDivisionError': ZeroDivisionError,
#    '__IPYTHON__': True,
#    '__build_class__': <function __build_class__>,
#    '__debug__': True,
#    '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#    '__import__': <function __import__>,
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__name__': 'builtins',
#    '__package__': '',
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#    'abs': <function abs>,
#    'all': <function all>,
#    'any': <function any>,
#    'ascii': <function ascii>,
#    'bin': <function bin>,
#    'bool': bool,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'callable': <function callable>,
#    'chr': <function chr>,
#    'classmethod': classmethod,
#    'compile': <function compile>,
#    'complex': complex,
#    'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#        for supporting Python development.  See www.python.org for more information.,
#    'delattr': <function delattr>,
#    'dict': dict,
#    'dir': <function dir>,
#    'divmod': <function divmod>,
#    'dreload': <function IPython.lib.deepreload._dreload>,
#    'enumerate': enumerate,
#    'eval': <function eval>,
#    'exec': <function exec>,
#    'filter': filter,
#    'float': float,
#    'format': <function format>,
#    'frozenset': frozenset,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#    'getattr': <function getattr>,
#    'globals': <function globals>,
#    'hasattr': <function hasattr>,
#    'hash': <function hash>,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    'hex': <function hex>,
#    'id': <function id>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10b7743c8>>,
#    'int': int,
#    'isinstance': <function isinstance>,
#    'issubclass': <function issubclass>,
#    'iter': <function iter>,
#    'len': <function len>,
#    'license': Type license() to see the full license text,
#    'list': list,
#    'locals': <function locals>,
#    'map': map,
#    'max': <function max>,
#    'memoryview': memoryview,
#    'min': <function min>,
#    'next': <function next>,
#    'object': object,
#    'oct': <function oct>,
#    'open': <function io.open>,
#    'ord': <function ord>,
#    'pow': <function pow>,
#    'print': <function print>,
#    'property': property,
#    'range': range,
#    'repr': <function repr>,
#    'reversed': reversed,
#    'round': <function round>,
#    'set': set,
#    'setattr': <function setattr>,
#    'slice': slice,
#    'sorted': <function sorted>,
#    'staticmethod': staticmethod,
#    'str': str,
#    'sum': <function sum>,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'vars': <function vars>,
#    'zip': zip},
#   13: {...}},
#  '_sh': <module 'IPython.core.shadowns' from '/usr/local/lib/python3.6/site-packages/IPython/core/shadowns.py'>,
#  'a': 1,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10b7d36a0>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10b7614a8>>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10b7d36a0>}

# %%
locals()==globals()
# Out:
# True

# %% [markdown]
# The namespace containing the built-in names is created when the Python interpreter starts up, and [is never deleted](http://www.python-course.eu/namespaces.php).

# %% [markdown]
#     globals()
#
#     Return a dictionary representing the current global symbol table. This is always the dictionary of the current module (inside a function or method, this is the module where it is defined, not the module from which it is called).

# %%
help(locals())
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
help(pop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-1269a6e57a6e> in <module>()
# ----> 1 help(pop)
#
# NameError: name 'pop' is not defined

# %%
dir()
# Out:
# ['A',
#  'In',
#  'Out',
#  '_',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_34',
#  '_36',
#  '_37',
#  '_38',
#  '_4',
#  '_47',
#  '_48',
#  '_49',
#  '_5',
#  '_50',
#  '_51',
#  '_59',
#  '_6',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'a',
#  'exit',
#  'get_ipython',
#  'i',
#  'inspect',
#  'quit',
#  'types',
#  'x']
